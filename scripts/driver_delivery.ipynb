# %%
import pandas as pd

# %%
df1 = pd.read_csv('deliveries.csv')
df2 = pd.read_csv('drivers.csv')

# %%
df1.head()
# Out:
#    delivery_id  delivery_order_id  driver_id  delivery_distance_meters  \
# 0      2174658           68413340     8378.0                    5199.0
# 1      2174660           68414309     2473.0                     410.0
# 2      2174661           68416230     7615.0                    3784.0
# 3      2174663           68412721     8378.0                    5714.0
# 4      2174675           68414018    10463.0                    3746.0
#
#   delivery_status
# 0       DELIVERED
# 1       DELIVERED
# 2       DELIVERED
# 3       DELIVERED
# 4       DELIVERED

# %%
df2.head()
# Out:
#    driver_id driver_modal        driver_type                   Email Address  \
# 0        133      MOTOBOY  LOGISTIC OPERATOR  Melania_Corbett1764@elnee.tech
# 1        138      MOTOBOY          FREELANCE  Esmeralda_Bryson759@iatim.tech
# 2        140      MOTOBOY          FREELANCE      Carter_Watson705@liret.org
# 3        143        BIKER          FREELANCE     Alexia_Flack6738@bauros.biz
# 4        148      MOTOBOY          FREELANCE    Gloria_Mooney2402@mafthy.com
#
#   FirstName LastName    Phone Number
# 0    Melania Corbett  8-705-716-1533
# 1   Esmeralda Bryson  7-351-106-3760
# 2      Carter Watson  0-606-865-2551
# 3       Alexia Flack  2-835-481-7156
# 4      Gloria Mooney  2-178-035-0625

# %%
df =df1.merge(df2,left_on='driver_id',right_on='driver_id')

# %%
df.head()
# Out:
#    delivery_id  delivery_order_id  driver_id  delivery_distance_meters  \
# 0      2174658           68413340     8378.0                    5199.0
# 1      2174663           68412721     8378.0                    5714.0
# 2      2175006           68424238     8378.0                    5389.0
# 3      2175302           68423436     8378.0                    5052.0
# 4      2175636           68457718     8378.0                    3249.0
#
#   delivery_status driver_modal driver_type               Email Address  \
# 0       DELIVERED      MOTOBOY   FREELANCE  Cara_Fulton2597@typill.biz
# 1       DELIVERED      MOTOBOY   FREELANCE  Cara_Fulton2597@typill.biz
# 2       DELIVERED      MOTOBOY   FREELANCE  Cara_Fulton2597@typill.biz
# 3       DELIVERED      MOTOBOY   FREELANCE  Cara_Fulton2597@typill.biz
# 4       DELIVERED      MOTOBOY   FREELANCE  Cara_Fulton2597@typill.biz
#
#   FirstName LastName    Phone Number
# 0        Cara Fulton  1-470-102-6607
# ...

# %%
df.drop(['driver_id'],axis=1,inplace=True)

# %%
new_df= df.iloc[:100000]

# %%
new_df.to_csv('delivery_driver.txt',index=false)
