# %%
import pandas as pd

# %%
orders = pd.read_csv('orders_add.csv')

# %%
orders.head()
# Out:
#    order_id  store_id  channel_id  payment_order_id  delivery_order_id  \
# 0  85579237      3068           5          85579237           85579237
# 1  86862263      3631          35          86862263           86862263
# 2  77332755       616          15          77332755           77332755
# 3  76366587      1037           5          76366587           76366587
# 4  85895389       707           5          85895389           85895389
#
#   order_status  order_amount  order_delivery_fee  order_delivery_cost  \
# 0     FINISHED          21.0                0.00                 5.61
# 1     FINISHED          99.9                9.90                10.00
# 2     FINISHED          27.0                3.99                10.61
# 3     FINISHED         113.7               11.90                10.56
# 4     FINISHED          62.4               11.90                 8.13
#
#    order_created_hour  ...  order_moment_finished  \
# 0                  17  ...        3/23/2021 17:43
# ...

# %%
orders['order Time'] = orders['Order Date'].map(lambda x : x.split(' ')[1])
orders['Order Date'] = orders['Order Date'].map(lambda x : x.split(' ')[0])
orders['Delivered Time'] = orders['Delivered Date'].map(lambda x : x.split(' ')[1])
orders['Delivered Date'] = orders['Delivered Date'].map(lambda x : x.split(' ')[0])

# %%
orders.head()
# Out:
#    order_id  store_id  channel_id  payment_order_id  delivery_order_id  \
# 0  85579237      3068           5          85579237           85579237
# 1  86862263      3631          35          86862263           86862263
# 2  77332755       616          15          77332755           77332755
# 3  76366587      1037           5          76366587           76366587
# 4  85895389       707           5          85895389           85895389
#
#   order_status  order_amount  order_delivery_fee  order_delivery_cost  \
# 0     FINISHED          21.0                0.00                 5.61
# 1     FINISHED          99.9                9.90                10.00
# 2     FINISHED          27.0                3.99                10.61
# 3     FINISHED         113.7               11.90                10.56
# 4     FINISHED          62.4               11.90                 8.13
#
#    order_created_hour  ...  order_metric_paused_time  \
# 0                  17  ...                      0.68
# ...

# %%
orders['order Time Hour'] = orders['order Time'].map(lambda x : x.split(':')[0])
orders['Order Date Minute'] = orders['order Time'].map(lambda x : x.split(':')[1])
orders.drop(['order Time'],axis=1,inplace=True)
orders['Delivered Time Hour'] = orders['Delivered Time'].map(lambda x : x.split(':')[0])
orders['Delivered Date Minute'] = orders['Delivered Time'].map(lambda x : x.split(':')[1])
orders.drop(['Delivered Time'],axis=1,inplace=True)

# %%
orders.head()
# Out:
#    order_id  store_id  channel_id  payment_order_id  delivery_order_id  \
# 0  85579237      3068           5          85579237           85579237
# 1  86862263      3631          35          86862263           86862263
# 2  77332755       616          15          77332755           77332755
# 3  76366587      1037           5          76366587           76366587
# 4  85895389       707           5          85895389           85895389
#
#   order_status  order_amount  order_delivery_fee  order_delivery_cost  \
# 0     FINISHED          21.0                0.00                 5.61
# 1     FINISHED          99.9                9.90                10.00
# 2     FINISHED          27.0                3.99                10.61
# 3     FINISHED         113.7               11.90                10.56
# 4     FINISHED          62.4               11.90                 8.13
#
#    order_created_hour  ...  order_metric_walking_time  \
# 0                  17  ...                       5.08
# ...

# %%
orders.columns
# Out:
# Index(['order_id', 'store_id', 'channel_id', 'payment_order_id',
#        'delivery_order_id', 'order_status', 'order_amount',
#        'order_delivery_fee', 'order_delivery_cost', 'order_created_hour',
#        'order_created_minute', 'order_created_day', 'order_created_month',
#        'order_created_year', 'order_moment_created', 'order_moment_accepted',
#        'order_moment_ready', 'order_moment_collected',
#        'order_moment_in_expedition', 'order_moment_delivering',
#        'order_moment_delivered', 'order_moment_finished',
#        'order_metric_collected_time', 'order_metric_paused_time',
#        'order_metric_production_time', 'order_metric_walking_time',
#        'order_metric_expediton_speed_time', 'order_metric_transit_time',
#        'order_metric_cycle_time', 'Order Date', 'Delivered Date',
#        'order Time Hour', 'Order Date Minute', 'Delivered Time Hour',
#        'Delivered Date Minute'],
#       dtype='object')

# %%
colls = ['order_id','Order Date','Order Date', 'Delivered Date',
       'order Time Hour', 'Order Date Minute', 'Delivered Time Hour',
       'Delivered Date Minute']

# %%
compile = orders[colls]

# %%
compile.head()
# Out:
#    order_id Order Date Order Date Delivered Date order Time Hour  \
# 0  85579237   3/8/2021   3/8/2021      3/12/2021              16
# 1  86862263   9/5/2020   9/5/2020       9/7/2020               9
# 2  77332755  7/12/2020  7/12/2020      7/16/2020              15
# 3  76366587  6/30/2021  6/30/2021       7/4/2021              10
# 4  85895389   4/5/2019   4/5/2019       4/7/2019              10
#
#   Order Date Minute Delivered Time Hour Delivered Date Minute
# 0                22                   5                    53
# 1                11                  22                    30
# 2                00                   7                    51
# 3                36                   2                    01
# 4                12                  18                    12

# %%
compile.shape
# Out:
# (57521, 8)

# %%
compile.to_csv('orders_date.csv',index=False)
